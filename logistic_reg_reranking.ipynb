# %% [markdown]
# # VPR Project Part 2

# %% [markdown]
# ## 1. Clone clode from git

# %%
# !git clone --recursive https://github.com/AxelBadouel/Visual-Place-Recognition-Project
# Out:
# Cloning into 'Visual-Place-Recognition-Project'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 173 (delta 28), reused 24 (delta 14), pack-reused 112 (from 4)
# Receiving objects: 100% (173/173), 1.40 MiB | 8.46 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Submodule 'image-matching-models' (https://github.com/alexstoken/image-matching-models.git) registered for path 'image-matching-models'
# Cloning into '/content/Visual-Place-Recognition-Project/image-matching-models'...
# remote: Enumerating objects: 2853, done.
# remote: Counting objects: 100% (1247/1247), done.
# remote: Compressing objects: 100% (377/377), done.
# remote: Total 2853 (delta 987), reused 886 (delta 868), pack-reused 1606 (from 1)
# Receiving objects: 100% (2853/2853), 84.38 MiB | 11.44 MiB/s, done.
# Resolving deltas: 100% (2024/2024), done.
# ...

# %% [markdown]
# ## 2. Installation of dependencies

# %%
# !pip install -r /content/Visual-Place-Recognition-Project/image-matching-models/requirements.txt
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 76.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.5/745.5 kB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.3/225.3 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 99.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 83.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 3. Downloading of the datasets

# %%
# !python /content/Visual-Place-Recognition-Project/download_datasets.py
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=15QB3VNKj93027UAQWv7pzFQO1JDCdZj2
# From (redirected): https://drive.google.com/uc?id=15QB3VNKj93027UAQWv7pzFQO1JDCdZj2&confirm=t&uuid=221742a9-0108-4306-8c05-517ae7420464
# To: /content/data/tokyo_xs.zip
# 100% 141M/141M [00:02<00:00, 64.5MB/s]
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1tQqEyt3go3vMh4fj_LZrRcahoTbzzH-y
# From (redirected): https://drive.google.com/uc?id=1tQqEyt3go3vMh4fj_LZrRcahoTbzzH-y&confirm=t&uuid=2a792eb8-fa53-4822-b05f-bee3e5e26380
# To: /content/data/sf_xs.zip
# 100% 1.03G/1.03G [00:11<00:00, 87.7MB/s]
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1q7usSe9_5xV5zTfN-1In4DlmF5ReyU_A
# From (redirected): https://drive.google.com/uc?id=1q7usSe9_5xV5zTfN-1In4DlmF5ReyU_A&confirm=t&uuid=2547cc4e-fe21-446f-814d-7dee4e542094
# To: /content/data/gsv_xs.zip
# 100% 5.67G/5.67G [01:15<00:00, 75.1MB/s]
# ...
# Downloading...
# ...

# %% [markdown]
# ## 4. Retrieval of the R@1

# %%
distance_metric = f"L2"
training_database = f"/content/data/svox/images/train/gallery /content/data/svox/images/train/gallery"
validation_database = f"/content/data/svox/images/val/gallery"
training_queries = f"/content/data/svox/images/train/queries_sun /content/data/svox/images/train/queries_night"
validation_queries = f"/content/data/svox/images/val/queries"
recall_values = f"1"

# %% [markdown]
# Cosplace Retrieval

# %%
# !python /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py \
    --num_workers 2 \
    --batch_size 32 \
    --log_dir log_dir \
    --method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
    --image_size 512 512 \
    --database_folder $training_database \
    --queries_folder $training_queries \
    --num_preds_to_save 20 \
    --recall_values 1\
    --distance_metric $distance_metric
# Out:
# 2026-08-26 13:06:44 /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py --num_workers 2 --batch_size 32 --log_dir log_dir --method=cosplace --backbone=ResNet18 --descriptors_dimension=512 --image_size 512 512 --database_folder /content/data/svox/images/train/gallery /content/data/svox/images/train/gallery --queries_folder /content/data/svox/images/train/queries_sun /content/data/svox/images/train/queries_night --num_preds_to_save 20 --recall_values 1 --distance_metric L2
# ...

# %%
# !python /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py \
    --num_workers 2 \
    --batch_size 32 \
    --log_dir log_dir \
    --method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
    --image_size 512 512 \
    --database_folder $validation_database \
    --queries_folder $validation_queries \
    --num_preds_to_save 20 \
    --recall_values 1\
    --distance_metric $distance_metric
# Out:
# 2026-08-26 13:16:33 /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py --num_workers 2 --batch_size 32 --log_dir log_dir --method=cosplace --backbone=ResNet18 --descriptors_dimension=512 --image_size 512 512 --database_folder /content/data/svox/images/val/gallery /content/data/svox/images/val/gallery --queries_folder /content/data/svox/images/val/queries /content/data/svox/images/val/queries --num_preds_to_save 20 --recall_values 1 --distance_metric L2
# ...

# %% [markdown]
# MegaLoc Retrieval

# %%
# !python /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py \
    --num_workers 8 \
    --batch_size 32 \
    --log_dir log_dir \
    --method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
    --image_size 322 322 \
    --database_folder $training_database \
    --queries_folder $training_queries \
    --num_preds_to_save 20 \
    --recall_values 1 \
    --distance_metric $distance_metric
# Out:
# 2026-08-26 14:03:03 /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py --num_workers 8 --batch_size 32 --log_dir log_dir --method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 --image_size 322 322 --database_folder /content/data/svox/images/train/gallery /content/data/svox/images/train/gallery --queries_folder /content/data/svox/images/train/queries_sun /content/data/svox/images/train/queries_night --num_preds_to_save 20 --recall_values 1 --distance_metric L2
# ...

# %%
# !python /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py \
    --num_workers 8 \
    --batch_size 32 \
    --log_dir log_dir \
    --method=megaloc --backbone=Dinov2 --descriptors_dimension=512 \
    --image_size 322 322 \
    --database_folder $validation_database \
    --queries_folder $validation_queries \
    --num_preds_to_save 20 \
    --recall_values 1 \
    --distance_metric $distance_metric
# Out:
# 2026-08-26 14:29:33 /content/Visual-Place-Recognition-Project/VPR-methods-evaluation/main.py --num_workers 8 --batch_size 32 --log_dir log_dir --method=megaloc --backbone=Dinov2 --descriptors_dimension=512 --image_size 322 322 --database_folder /content/data/svox/images/val/gallery /content/data/svox/images/val/gallery --queries_folder /content/data/svox/images/val/queries /content/data/svox/images/val/queries --num_preds_to_save 20 --recall_values 1 --distance_metric L2
# ...

# %% [markdown]
# ## 5. Image Matching

# %%
retrieved_cosplace_training_predictions = " ".join(["/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44/preds", "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44/preds"])
retrieved_cosplace_validation_predictions = " ".join(["/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33/preds"])
retrieved_megaloc_training_predictions = " ".join(["/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03/preds", "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20/preds"])
retrieved_megaloc_validation_predictions = " ".join(["/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-29-33/preds "])

# %% [markdown]
# SuperGlue

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_cosplace_training_predictions} \
    --matcher 'superglue' \
    --device 'cuda' \
    --num-preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/imatch-toolbox/immatch/modules/../../third_party/patch2pix/networks/ncn/model.py:233: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   if checkpoint is not None and checkpoint is not '':
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/imatch-toolbox/immatch/modules/../../third_party/patch2pix/networks/ncn/model.py:264: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   if checkpoint is not None and checkpoint is not '':
# ...

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_cosplace_validation_predictions} \
    --matcher 'superglue' \
    --device 'cuda' \
    --num-preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#   0% 0/14698 [00:00<?, ?it/s]/content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/imatch-toolbox/third_party/superglue/models/superpoint.py:88: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   descriptors = torch.nn.functional.grid_sample(
# 100% 14698/14698 [2:33:49<00:00,  1.59it/s]

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_megaloc_training_predictions} \
    --matcher 'superglue' \
    --device 'cuda' \
    --num-preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#   0% 0/712 [00:00<?, ?it/s]/content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/imatch-toolbox/third_party/superglue/models/superpoint.py:88: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   descriptors = torch.nn.functional.grid_sample(
# 100% 712/712 [02:07<00:00,  5.60it/s]
# 100% 702/702 [02:00<00:00,  5.80it/s]

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_megaloc_validation_predictions} \
    --matcher 'superglue' \
    --device 'cuda' \
    --num-preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
#   0% 0/579 [00:00<?, ?it/s]/content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/imatch-toolbox/third_party/superglue/models/superpoint.py:88: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   descriptors = torch.nn.functional.grid_sample(
# 100% 579/579 [01:52<00:00,  5.15it/s]

# %% [markdown]
# Loftr

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_cosplace_training_predictions} \
    --matcher 'loftr' \
    --device 'cuda' \
    --num_preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# 100% 712/712 [00:00<00:00, 1482.49it/s]
# 100% 702/702 [03:03<00:00,  3.84it/s]

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_cosplace_validation_predictions} \
    --matcher 'loftr' \
    --device 'cuda' \
    --num_preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# 100% 14698/14698 [2:18:30<00:00,  1.77it/s]

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_megaloc_training_predictions} \
    --matcher 'loftr' \
    --device 'cuda' \
    --num_preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# 100% 712/712 [00:00<00:00, 1424.18it/s]
# 100% 702/702 [03:07<00:00,  3.75it/s]

# %%
# !python /content/Visual-Place-Recognition-Project/match_queries_preds.py \
    --preds-dir {retrieved_megaloc_validation_predictions} \
    --matcher 'loftr' \
    --device 'cuda' \
    --num_preds 20
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/matching/third_party/LightGlue/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# 100% 579/579 [00:00<00:00, 1434.87it/s]

# %% [markdown]
# ## 6. Logistic Regression Training and Validation

# %% [markdown]
# ### Inliers extraction for training and testing

# %%
# Data relative to the sun dataset
svox_train_sun_preds_folder = " ".join([
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44_cosplace_train_sun/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44_cosplace_train_sun/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03_megaloc_train_sun/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03_megaloc_train_sun/preds"
])

svox_train_sun_inliers_folder = " ".join([
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44_cosplace_train_sun/preds_loftr",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44_cosplace_train_sun/preds_superglue",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03_megaloc_train_sun/preds_loftr",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03_megaloc_train_sun/preds_superglue"
  ])

# Data relative to the sun dataset
svox_train_night_preds_folder = " ".join([
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44_cosplace_train_night/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44_cosplace_train_night/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20_megaloc_train_night/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20_megaloc_train_night/preds"
])

svox_train_night_inliers_folder = " ".join([
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44_cosplace_train_night/preds_loftr",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44_cosplace_train_night/preds_superglue",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20_megaloc_train_night/preds_loftr",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20_megaloc_train_night/preds_superglue"
  ])

# Validation data material
svox_val_preds_folder = " ".join([
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-29-33_megaloc_val/preds",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-29-33_megaloc_val/preds"
])

svox_val_inliers_folder = " ".join([
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/preds_loftr",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/preds_superglue",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-29-33_megaloc_val/preds_loftr",
    "/content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-29-33_megaloc_val/preds_superglue"
  ])

# %%
# !python /content/Visual-Place-Recognition-Project/logistic_regression/dataset_constructor.py \
    --preds_dir {svox_train_sun_preds_folder} \
    --inliers_dir {svox_train_sun_inliers_folder} \
    --num-preds 20
# Out:
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44/preds
# Folder has something in it!
# 100% 712/712 [03:52<00:00,  3.06it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44/loftr.csv
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44/preds
# Folder has something in it!
# 100% 712/712 [03:10<00:00,  3.74it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-06-44/superglue.csv
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03/preds
# Folder has something in it!
# 100% 712/712 [03:19<00:00,  3.58it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-03-03/loftr.csv
# ...

# %%
# !python /content/Visual-Place-Recognition-Project/logistic_regression/dataset_constructor.py \
    --preds_dir {svox_train_night_preds_folder} \
    --inliers_dir {svox_train_night_inliers_folder} \
    --num-preds 20
# Out:
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44/preds
# Folder has something in it!
# 100% 702/702 [03:17<00:00,  3.56it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44/loftr.csv
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44/preds
# Folder has something in it!
# 100% 702/702 [02:58<00:00,  3.94it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-11-44/superglue.csv
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20/preds
# Folder has something in it!
# 100% 702/702 [03:28<00:00,  3.37it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-16-20/loftr.csv
# ...

# %%
# !python /content/Visual-Place-Recognition-Project/logistic_regression/dataset_constructor.py \
    --preds_dir {svox_val_preds_folder} \
    --inliers_dir {svox_val_inliers_folder} \
    --num-preds 20
# Out:
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/preds
# Folder has something in it!
# 100% 14698/14698 [1:03:06<00:00,  3.88it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/loftr.csv
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/preds
# Folder has something in it!
# 100% 14698/14698 [58:59<00:00,  4.15it/s]
# Saved results to /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_13-16-33_cosplace_val/superglue.csv
# folder name: /content/drive/MyDrive/Colab_Notebooks/Section_6_folder/logs/log_dir/log_dir/2026-08-26_14-29-33_megaloc_val/preds
# Folder has something in it!
# 100% 579/579 [02:25<00:00,  3.97it/s]
# ...

# %% [markdown]
# ### Training of the classifier

# %% [markdown]
# ## 7. Logistic Regression Testing and Reranking

# %% [markdown]
# The output from section 5 is now used for testing

# %%
databases = f"/content/data/svox/images/test/gallery /content/data/svox/images/test/gallery"
queries = f"/content/data/svox/images/test/queries_sun /content/data/svox/images/test/queries_night"
predictions = f""
inliers = f""

# %% [markdown]
# If the logistic regression upon looking at the R@1 prediction for a query classifies it as "hard", then the reranking is triggered else it is not triggered

# %% [markdown]
# ##
